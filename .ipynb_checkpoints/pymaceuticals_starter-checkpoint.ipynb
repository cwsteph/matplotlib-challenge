# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# #### Observation 1)
#
# Capumolin and Ramicane were drug regiments that were used the most in the test subjects.
#
# #### Observation 2)
#
# The gender of mice is equal, making the test results more valid by eliminating a possible variable from the data.
#
# #### Observation 3)
#
# There is a slight coorelation weight and tumor size.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "Mouse_metadata.csv"
study_results_path = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)

study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset

merged_df = pd.merge(mouse_metadata, study_results, how='inner')
merged_df

merged_df = pd.DataFrame(merged_df)
merged_df

# Display the data table for preview
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.

unique_mouse_ID = len(merged_df["Mouse ID"].unique())
unique_mouse_ID
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_mouse = merged_df.loc[merged_df.duplicated(subset = ["Mouse ID", "Timepoint"]), "Mouse ID"]
duplicate_mouse
# Out:
# 909    g989
# 911    g989
# 913    g989
# 915    g989
# 917    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 

duplicate_mouse_data = merged_df[merged_df['Mouse ID'] == 'g989']
duplicate_mouse_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

clean_mouse_data = merged_df[merged_df['Mouse ID'] != 'g989']
clean_mouse_data

clean_mouse_data =pd.DataFrame(clean_mouse_data)
clean_mouse_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.

clean_data_count = len(clean_mouse_data["Mouse ID"].unique())
clean_data_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 

drug_data = clean_mouse_data.groupby('Drug Regimen')

drug_data_mean = drug_data.mean()['Tumor Volume (mm3)']

drug_data_median = drug_data.median()['Tumor Volume (mm3)']

drug_data_variance = drug_data.var()['Tumor Volume (mm3)']

drug_data_std = drug_data.std()['Tumor Volume (mm3)']

drug_data_sem = drug_data.sem()['Tumor Volume (mm3)']


summary_stats_df = pd.DataFrame({'Mean': drug_data_mean , "Median" : drug_data_median, "Variance" : drug_data_variance,
                                "STD" : drug_data_std, "SEM" : drug_data_sem})
summary_stats_df


# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
# Out:
#                    Mean     Median   Variance       STD       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

drug_data = clean_mouse_data.groupby('Drug Regimen')

drug_data_summary = drug_data.agg({'Tumor Volume (mm3)':['mean', "median", 'var', 'std', 'sem']})
drug_data_summary
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.

drug_data = clean_mouse_data['Drug Regimen'].value_counts()
drug_data

drug_data.plot(kind = 'bar')

plt.ylabel('Mice Count')
plt.title('Drug Regimen')
plt.show()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

drug_data = clean_mouse_data['Drug Regimen'].value_counts()

plt.bar(drug_data.index.values, drug_data.values)
plt.xticks(rotation = 90)

plt.ylabel('Mice Count')
plt.title('Drug Regimen')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

drug_data = clean_mouse_data['Sex'].value_counts()
drug_data

drug_data.plot(kind = 'pie', autopct = '%1.2f%%')

plt.title('Mouse Gender')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

drug_data = clean_mouse_data['Sex'].value_counts()

plt.pie(drug_data.values, labels = drug_data.index.values, autopct = '%1.2f%%')

plt.title('Mouse Gender')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

#Start by getting the last (greatest) timepoint for each mouse
final_mouse_id = clean_mouse_data.groupby(['Mouse ID'])
final_time = final_mouse_id['Timepoint'].max()
final_time

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

merged_id_time = pd.merge(final_time, clean_mouse_data, how='inner', on = 'Timepoint')
merged_id_time.set_index(["Mouse ID"])

# merged_id_time =pd.DataFrame.sort_index(merged_id_time)
# merged_id_time

merged_id_time = merged_id_time.drop_duplicates('Mouse ID')
merged_id_time
# Out:
#        Timepoint Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  \
# 0             45     k403     Ramicane    Male          21          16
# 1             45     s185    Capomulin  Female           3          17
# 2             45     x401    Capomulin  Female          16          15
# 3             45     m601    Capomulin    Male          22          17
# 4             45     g791     Ramicane    Male          11          16
# ...          ...      ...          ...     ...         ...         ...
# 25737          0     x226     Ceftamin    Male          23          28
# 25739          0     x336     Naftisol  Female           4          29
# 25749          0     y601     Naftisol  Female          23          25
# 25752          0     z234     Naftisol  Female          19          27
# 25753          0     z314     Stelasyn  Female          21          28
#
#        Tumor Volume (mm3)  Metastatic Sites
# 0               22.050126                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

drugs = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']


# Create empty list to fill with tumor vol data (for plotting)

plot_list = []


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
#Determine outliers using upper and lower bounds

for x in drugs:
    final_drug_tumor_vol = merged_id_time.loc[merged_id_time['Drug Regimen'] == x, 'Tumor Volume (mm3)']
    plot_list.append(final_drug_tumor_vol)
    quartiles = final_drug_tumor_vol.quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    #outliers = [z for z in final_drug_tumor_vol if (z < lower_bound) (z > upper_bound)]
    
print(f"The IQR data for {x}:")
print(f"The lower quartile of {x} is: {lowerq}:")
print(f"The upper quartile of {x} is: {upperq}:")
print(f"The interquartile range of {x} is: {iqr}")
print(f"The the median of {x} is: {quartiles[0.5]} ")
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The IQR data for Ceftamin:
# The lower quartile of Ceftamin is: 47.40483439:
# The upper quartile of Ceftamin is: 64.29983003:
# The interquartile range of Ceftamin is: 16.894995639999998
# The the median of Ceftamin is: 59.74190064
# Values below 22.06234093 could be outliers.
# Values above 89.64232349 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume by Drug')
ax1.set_xlabel('Drug Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(plot_list, notch = 0, sym='gD')
plt.xticks([1,2,3,4], drugs)

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

capomulin = clean_mouse_data.loc[clean_mouse_data['Drug Regimen'] == 'Capomulin']
capomulin

#capomulin = capomulin.drop_duplicates(['Mouse ID'])
#capomulin


#pick any mouse ID you want using Capomulin
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

scatter_df = capomulin[["Mouse ID","Weight (g)", "Tumor Volume (mm3)"]]
scatter_df

    
capomulin_scatter = capomulin_scatter_df.plot(kind='scatter', x='Weight (g)', y='Tumor Volume (mm3)', grid = True, figsize= (8,8), title="Weight and Tumor Volume")
capomulin_scatter
# Out:
# <AxesSubplot:title={'center':'Weight and Tumor Volume'}, xlabel='Weight (g)', ylabel='Tumor Volume (mm3)'>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 

weight = capomulin.iloc[:,4]
tumor = capomulin.iloc[:,6]
correlation = st.pearsonr(weight,tumor)
plt.scatter(weight,tumor)
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()


# for mouse weight and average tumor volume for the Capomulin regimen
# Out:
# The correlation between both factors is 0.53
